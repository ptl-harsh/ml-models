# %% [markdown]
# Linear regression in Python

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv("/content/drive/MyDrive/hackslash/USA_Housing2.csv")

# %%
df.head()
# Out:
#    Avg_Area_Income  Avg_Area_House_Age  Avg_Area_Number_of_Rooms  \
# 0     79545.458574            5.682861                  7.009188
# 1     79248.642455            6.002900                  6.730821
# 2     61287.067179            5.865890                  8.512727
# 3     63345.240046            7.188236                  5.586729
# 4     59982.197226            5.040555                  7.839388
#
#    Avg_Area_Number_of_Bedrooms  Area_Population         Price  \
# 0                         4.09     23086.800503  1.059034e+06
# 1                         3.09     40173.072174  1.505891e+06
# 2                         5.13     36882.159400  1.058988e+06
# 3                         3.26     34310.242831  1.260617e+06
# 4                         4.23     26354.109472  6.309435e+05
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# ...

# %%
df.columns
# Out:
# Index(['Avg_Area_Income', 'Avg_Area_House_Age', 'Avg_Area_Number_of_Rooms',
#        'Avg_Area_Number_of_Bedrooms', 'Area_Population', 'Price', 'Address'],
#       dtype='object')

# %%
df.describe()
# Out:
#        Avg_Area_Income  Avg_Area_House_Age  Avg_Area_Number_of_Rooms  \
# count      5000.000000         5000.000000               5000.000000
# mean      68583.108984            5.977222                  6.987792
# std       10657.991214            0.991456                  1.005833
# min       17796.631190            2.644304                  3.236194
# 25%       61480.562388            5.322283                  6.299250
# 50%       68804.286404            5.970429                  7.002902
# 75%       75783.338666            6.650808                  7.665871
# max      107701.748378            9.519088                 10.759588
#
#        Avg_Area_Number_of_Bedrooms  Area_Population         Price
# count                  5000.000000      5000.000000  5.000000e+03
# mean                      3.981330     36163.516039  1.232073e+06
# std                       1.234137      9925.650114  3.531176e+05
# min                       2.000000       172.610686  1.593866e+04
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Avg_Area_Income              5000 non-null   float64
#  1   Avg_Area_House_Age           5000 non-null   float64
#  2   Avg_Area_Number_of_Rooms     5000 non-null   float64
#  3   Avg_Area_Number_of_Bedrooms  5000 non-null   float64
#  4   Area_Population              5000 non-null   float64
#  5   Price                        5000 non-null   float64
#  6   Address                      5000 non-null   object
# dtypes: float64(6), object(1)
# memory usage: 273.6+ KB

# %%
features=["Avg_Area_Income","Avg_Area_Number_of_Rooms","Avg_Area_Number_of_Bedrooms","Area_Population"]
for feature in features:
  sns.lmplot(x=feature,y="Price",scatter=True,data=df)

# %%
plt.figure(figsize=(20,10))
sns.barplot(x="Avg_Area_House_Age",y="Price",data=df)
# Out:
# <Axes: xlabel='Avg_Area_House_Age', ylabel='Price'>

# %%
df2=df.drop(labels="Avg_Area_House_Age",axis=1)

# %%
df2.head()
# Out:
#    Avg_Area_Income  Avg_Area_Number_of_Rooms  Avg_Area_Number_of_Bedrooms  \
# 0     79545.458574                  7.009188                         4.09
# 1     79248.642455                  6.730821                         3.09
# 2     61287.067179                  8.512727                         5.13
# 3     63345.240046                  5.586729                         3.26
# 4     59982.197226                  7.839388                         4.23
#
#    Area_Population         Price  \
# 0     23086.800503  1.059034e+06
# 1     40173.072174  1.505891e+06
# 2     36882.159400  1.058988e+06
# 3     34310.242831  1.260617e+06
# 4     26354.109472  6.309435e+05
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# 2  9127 Elizabeth Stravenue\nDanieltown, WI 06482...
# 3                          USS Barnett\nFPO AP 44820
# ...

# %% [markdown]
# Training a Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression

# %%
X=df2.drop(labels="Price",axis=1)
y=df2["Price"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.32, random_state=5)

# %%
lm = LinearRegression()
